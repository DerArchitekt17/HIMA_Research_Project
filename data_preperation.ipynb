# %%
import json
import os
import sys
import re
import unicodedata
import pandas as pd
from pathlib import Path
from typing import List, Dict
import argparse

# %%
# Readin
df = pd.read_csv('MedSynth_huggingface_final.csv')
df
# Out:
#                                                     Note  \
# 0      **1. Subjective:**\r\n\r\n   **Chief Complaint...
# 1      **1. Subjective:**\r\n\r\n   - **Chief Complai...
# 2      **1. Subjective:**\r\n\r\n**Chief Complaint (C...
# 3      **1. Subjective:**\r\n\r\n**Chief Complaint (C...
# 4      #####\r\n**1. Subjective:**\r\n\r\n**Chief Com...
# ...                                                  ...
# 10235  #####\r\n**1. Subjective:**\r\n   \r\n**Chief ...
# 10236  ### Gastroenterologist Medical Note\r\n\r\n###...
# 10237  **1. Subjective:**\r\n\r\n**Chief Complaint (C...
# 10238  #####\r\n**1. Subjective:**\r\n**Chief Complai...
# 10239  **1. Subjective:**\r\n\r\n**Chief Complaint (C...
#
#                                                 Dialogue   ICD10  \
# 0      [doctor]: Hello! It’s good to see you today. H...  M25562
# 1      [doctor] Hi there, how are you today?\r\n\r\n[...  M25562
# 2      [doctor] Good morning, how are you doing today...  M25562
# 3      [doctor] Good morning! How are you feeling tod...  M25562
# 4      [doctor]: Hello Mr. Doe, how are you doing tod...  M25562
# ...                                                  ...     ...
# 10235  [doctor]: Good morning. How are you doing toda...   B3781
# 10236  **Doctor:** Hi there, how are you doing today?...   B3781
# 10237  [doctor]: Hi Mr. Harris, how are you doing tod...   B3781
# 10238  [doctor]: Good morning, Ms. Lee. How are you d...   B3781
# 10239  [doctor]: Good morning. How are you doing toda...   B3781
#
#                  ICD10_desc
# 0         PAIN IN LEFT KNEE
# 1         PAIN IN LEFT KNEE
# 2         PAIN IN LEFT KNEE
# 3         PAIN IN LEFT KNEE
# 4         PAIN IN LEFT KNEE
# ...                     ...
# 10235  CANDIDAL ESOPHAGITIS
# 10236  CANDIDAL ESOPHAGITIS
# 10237  CANDIDAL ESOPHAGITIS
# 10238  CANDIDAL ESOPHAGITIS
# 10239  CANDIDAL ESOPHAGITIS
#
# [10240 rows x 4 columns]

# %%
# Harmonizing UTF characters
def clean_string(s):
    if not isinstance(s, str):
        return s

    s = unicodedata.normalize("NFKC", s)
    s = re.sub(r"[\u200b\u200c\u200d\ufeff]", "", s)
    s = re.sub(r"[\x00-\x1F\x7F]", "", s)
    s = re.sub(r"\s+", " ", s).strip()
    return s

df[["Note", "Dialogue"]] = df[["Note", "Dialogue"]].map(clean_string)
df
# Out:
#                                                     Note  \
# 0      **1. Subjective:** **Chief Complaint (CC):** -...
# 1      **1. Subjective:** - **Chief Complaint (CC):**...
# 2      **1. Subjective:****Chief Complaint (CC):**Sev...
# 3      **1. Subjective:****Chief Complaint (CC):** Mo...
# 4      #####**1. Subjective:****Chief Complaint (CC):...
# ...                                                  ...
# 10235  #####**1. Subjective:** **Chief Complaint (CC)...
# 10236  ### Gastroenterologist Medical Note#### 1. Sub...
# 10237  **1. Subjective:****Chief Complaint (CC):**Dif...
# 10238  #####**1. Subjective:****Chief Complaint (CC):...
# 10239  **1. Subjective:****Chief Complaint (CC):**The...
#
#                                                 Dialogue   ICD10  \
# 0      [doctor]: Hello! It’s good to see you today. H...  M25562
# 1      [doctor] Hi there, how are you today?[patient]...  M25562
# 2      [doctor] Good morning, how are you doing today...  M25562
# 3      [doctor] Good morning! How are you feeling tod...  M25562
# 4      [doctor]: Hello Mr. Doe, how are you doing tod...  M25562
# ...                                                  ...     ...
# 10235  [doctor]: Good morning. How are you doing toda...   B3781
# 10236  **Doctor:** Hi there, how are you doing today?...   B3781
# 10237  [doctor]: Hi Mr. Harris, how are you doing tod...   B3781
# 10238  [doctor]: Good morning, Ms. Lee. How are you d...   B3781
# 10239  [doctor]: Good morning. How are you doing toda...   B3781
#
#                  ICD10_desc
# 0         PAIN IN LEFT KNEE
# 1         PAIN IN LEFT KNEE
# 2         PAIN IN LEFT KNEE
# 3         PAIN IN LEFT KNEE
# 4         PAIN IN LEFT KNEE
# ...                     ...
# 10235  CANDIDAL ESOPHAGITIS
# 10236  CANDIDAL ESOPHAGITIS
# 10237  CANDIDAL ESOPHAGITIS
# 10238  CANDIDAL ESOPHAGITIS
# 10239  CANDIDAL ESOPHAGITIS
#
# [10240 rows x 4 columns]

# %%
# Erasing leading styling characters

s = df["Note"].astype("string")
df["Note"] = s.apply(lambda x: x[x.find("**"):] if isinstance(x, str) and "**" in x else x)
df
# Out:
#                                                     Note  \
# 0      **1. Subjective:** **Chief Complaint (CC):** -...
# 1      **1. Subjective:** - **Chief Complaint (CC):**...
# 2      **1. Subjective:****Chief Complaint (CC):**Sev...
# 3      **1. Subjective:****Chief Complaint (CC):** Mo...
# 4      **1. Subjective:****Chief Complaint (CC):** Mo...
# ...                                                  ...
# 10235  **1. Subjective:** **Chief Complaint (CC):**Di...
# 10236  **Chief Complaint (CC):** Difficulty swallowin...
# 10237  **1. Subjective:****Chief Complaint (CC):**Dif...
# 10238  **1. Subjective:****Chief Complaint (CC):** Se...
# 10239  **1. Subjective:****Chief Complaint (CC):**The...
#
#                                                 Dialogue   ICD10  \
# 0      [doctor]: Hello! It’s good to see you today. H...  M25562
# 1      [doctor] Hi there, how are you today?[patient]...  M25562
# 2      [doctor] Good morning, how are you doing today...  M25562
# 3      [doctor] Good morning! How are you feeling tod...  M25562
# 4      [doctor]: Hello Mr. Doe, how are you doing tod...  M25562
# ...                                                  ...     ...
# 10235  [doctor]: Good morning. How are you doing toda...   B3781
# 10236  **Doctor:** Hi there, how are you doing today?...   B3781
# 10237  [doctor]: Hi Mr. Harris, how are you doing tod...   B3781
# 10238  [doctor]: Good morning, Ms. Lee. How are you d...   B3781
# 10239  [doctor]: Good morning. How are you doing toda...   B3781
#
#                  ICD10_desc
# 0         PAIN IN LEFT KNEE
# 1         PAIN IN LEFT KNEE
# 2         PAIN IN LEFT KNEE
# 3         PAIN IN LEFT KNEE
# 4         PAIN IN LEFT KNEE
# ...                     ...
# 10235  CANDIDAL ESOPHAGITIS
# 10236  CANDIDAL ESOPHAGITIS
# 10237  CANDIDAL ESOPHAGITIS
# 10238  CANDIDAL ESOPHAGITIS
# 10239  CANDIDAL ESOPHAGITIS
#
# [10240 rows x 4 columns]

# %%
# Drop NA (and one abnormative) values

df.isna().sum()
df = df.drop([10236])
df = df.dropna()
df = df.sort_values(["ICD10", "Note"])
df.reset_index(inplace=True)
df = df.drop(["index"], axis=1)
df
# Out:
#                                                     Note  \
# 0      **1. Subjective:****Chief Complaint (CC):** Se...
# 1      **1. Subjective:****Chief Complaint (CC):**Fre...
# 2      **1. Subjective:****Chief Complaint (CC):**Mod...
# 3      **1. Subjective:****Chief Complaint (CC):**Wat...
# 4      **Subjective:****Chief Complaint (CC)**Severe ...
# ...                                                  ...
# 10232  **1. Subjective:****Chief Complaint (CC):**Fol...
# 10233  **1. Subjective:****Chief Complaint (CC):**Per...
# 10234  **1. Subjective:****Chief Complaint (CC):**Sev...
# 10235  **1. Subjective:****Chief Complaint (CC):**Sev...
# 10236  **1. Subjective:****Chief Complaint (CC):**Sev...
#
#                                                 Dialogue  ICD10  \
# 0      [doctor]: Good morning. How are you feeling to...   A047
# 1      [doctor]: Good morning, Mrs. Doe. How are you ...   A047
# 2      [doctor]: Hi Mr. Lee, how are you doing today?...   A047
# 3      [doctor]: Good morning, how are you today?[pat...   A047
# 4      [doctor]: Hi there, how are you doing today?[p...   A047
# ...                                                  ...    ...
# 10232  [doctor]: Good morning! It's nice to see you a...  Z9981
# 10233  ```markdown[doctor] Hello, how are you doing t...  Z9981
# 10234  [doctor] Good morning. How are you feeling tod...  Z9981
# 10235  [doctor] Hi Mr. Lee, how are you doing today?[...  Z9981
# 10236  [doctor]: Hi there, how are you feeling today?...  Z9981
#
#                                        ICD10_desc
# 0      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# 1      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# 2      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# 3      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# 4      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# ...                                           ...
# 10232           DEPENDENCE ON SUPPLEMENTAL OXYGEN
# 10233           DEPENDENCE ON SUPPLEMENTAL OXYGEN
# 10234           DEPENDENCE ON SUPPLEMENTAL OXYGEN
# 10235           DEPENDENCE ON SUPPLEMENTAL OXYGEN
# 10236           DEPENDENCE ON SUPPLEMENTAL OXYGEN
#
# [10237 rows x 4 columns]

# %%
# Extract SOAP sections from the note text

def extract_soap_sections(note):
    flags = re.DOTALL | re.IGNORECASE

    # Flexible section-start anchors (optional **, optional numbering, case-insensitive)
    obj_start  = r'(?:\*{0,2}\s*(?:\d+[\.\)]\s*)?Objective\s*[\*:]{0,3})'
    assess_start = r'(?:\*{0,2}\s*(?:\d+[\.\)]\s*)?Assessment\s*[\*:]{0,3})'
    plan_start = r'(?:\*{0,2}\s*(?:\d+[\.\)]\s*)?Plan\s*[\*:]{0,3})'

    # --- Subjective ---
    subj_pat = (
        r'(?:\*{0,2}\s*(?:\d+[\.\)]\s*)?'
        r'(?:Subjective|Chief\s+Complaint(?:\s*\(CC\))?)\s*[\*:]{0,3}\s*)'
        r'(.+?)(?=' + obj_start + r'|$)'
    )
    m = re.search(subj_pat, note, flags)
    if not m:
        # Fallback: everything before the Objective header is Subjective
        m = re.search(r'^(.+?)(?=' + obj_start + r')', note, flags)
    subjective = m.group(1).strip() if m else ''

    # --- Objective ---
    obj_pat = obj_start + r'\s*(.+?)(?=' + assess_start + r'|$)'
    m = re.search(obj_pat, note, flags)
    objective = m.group(1).strip() if m else ''

    # --- Assessment ---
    assess_pat = assess_start + r'\s*(.+?)(?=' + plan_start + r'|$)'
    m = re.search(assess_pat, note, flags)
    assessment = m.group(1).strip() if m else ''

    # --- Plan ---
    plan_pat = plan_start + r'\s*(.+?)$'
    m = re.search(plan_pat, note, flags)
    plan = m.group(1).strip() if m else ''

    return {
        'Subjective': subjective,
        'Objective': objective,
        'Assessment': assessment,
        'Plan': plan,
    }

soap_sections = df['Note'].apply(extract_soap_sections).apply(pd.Series)
df = pd.concat([df, soap_sections], axis=1)

# Drop rows where any SOAP dimension failed to extract
before = len(df)
df = df[(df['Subjective'] != '') & (df['Objective'] != '') & (df['Assessment'] != '') & (df['Plan'] != '')]
df = df.reset_index(drop=True)
print(f"Dropped {before - len(df)} rows with empty SOAP sections ({len(df)} remaining)")

df
# Out:
# Dropped 17 rows with empty SOAP sections (10220 remaining)
#                                                     Note  \
# 0      **1. Subjective:****Chief Complaint (CC):** Se...
# 1      **1. Subjective:****Chief Complaint (CC):**Fre...
# 2      **1. Subjective:****Chief Complaint (CC):**Mod...
# 3      **1. Subjective:****Chief Complaint (CC):**Wat...
# 4      **Subjective:****Chief Complaint (CC)**Severe ...
# ...                                                  ...
# 10215  **1. Subjective:****Chief Complaint (CC):**Fol...
# 10216  **1. Subjective:****Chief Complaint (CC):**Per...
# 10217  **1. Subjective:****Chief Complaint (CC):**Sev...
# 10218  **1. Subjective:****Chief Complaint (CC):**Sev...
# 10219  **1. Subjective:****Chief Complaint (CC):**Sev...
#
#                                                 Dialogue  ICD10  \
# 0      [doctor]: Good morning. How are you feeling to...   A047
# 1      [doctor]: Good morning, Mrs. Doe. How are you ...   A047
# 2      [doctor]: Hi Mr. Lee, how are you doing today?...   A047
# 3      [doctor]: Good morning, how are you today?[pat...   A047
# 4      [doctor]: Hi there, how are you doing today?[p...   A047
# ...                                                  ...    ...
# 10215  [doctor]: Good morning! It's nice to see you a...  Z9981
# 10216  ```markdown[doctor] Hello, how are you doing t...  Z9981
# 10217  [doctor] Good morning. How are you feeling tod...  Z9981
# 10218  [doctor] Hi Mr. Lee, how are you doing today?[...  Z9981
# 10219  [doctor]: Hi there, how are you feeling today?...  Z9981
#
#                                        ICD10_desc  \
# 0      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# 1      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# 2      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# 3      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# 4      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# ...                                           ...
# 10215           DEPENDENCE ON SUPPLEMENTAL OXYGEN
# 10216           DEPENDENCE ON SUPPLEMENTAL OXYGEN
# 10217           DEPENDENCE ON SUPPLEMENTAL OXYGEN
# 10218           DEPENDENCE ON SUPPLEMENTAL OXYGEN
# 10219           DEPENDENCE ON SUPPLEMENTAL OXYGEN
#
#                                               Subjective  \
# 0      **Chief Complaint (CC):** Severe abdominal pai...
# 1      **Chief Complaint (CC):**Frequent watery diarr...
# 2      **Chief Complaint (CC):**Moderate abdominal pa...
# 3      **Chief Complaint (CC):**Watery diarrhea and a...
# 4      **Chief Complaint (CC)**Severe abdominal cramp...
# ...                                                  ...
# 10215  **Chief Complaint (CC):**Follow-up for managem...
# 10216  **Chief Complaint (CC):**Persistent dry cough,...
# 10217  **Chief Complaint (CC):**Severe breathlessness...
# 10218  **Chief Complaint (CC):**Severe breathlessness...
# 10219  **Chief Complaint (CC):**Severe shortness of b...
#
#                                                Objective  \
# 0      **Vital Signs:**- Temperature: 100.8°F- Blood ...
# 1      **Vital Signs:**- Temperature: 100.5 °F- Blood...
# 2      This section is limited in a telemedicine enco...
# 3      - Physical Exam: Not applicable (telemedicine ...
# 4      **Vitals**- Temperature: 101.2 degrees F- Bloo...
# ...                                                  ...
# 10215  **Vital Signs:**- Blood Pressure: 138/82 mmHg-...
# 10216  **Physical Exam:**- **General:** Appears fatig...
# 10217  **Vital Signs:**- Blood Pressure: Not document...
# 10218  **Vital Signs:**- Blood Pressure: 140/85 mmHg-...
# 10219  **Vitals:**- BP: 130/85 mmHg- HR: 76 bpm- RR: ...
#
#                                               Assessment  \
# 0      **Diagnosis:** Enterocolitis due to Clostridiu...
# 1      - Enterocolitis due to Clostridium difficile (...
# 2      Diagnosis: Enterocolitis due to Clostridium di...
# 3      - Enterocolitis due to Clostridium difficile (...
# 4      1. Enterocolitis due to Clostridium difficile-...
# ...                                                  ...
# 10215  - **Chronic Obstructive Pulmonary Disease (COP...
# 10216  - Dependence on Supplemental Oxygen (ICD-10 Co...
# 10217  The patient presents with severe breathlessnes...
# 10218  - **Primary Diagnosis:** Dependence on Supplem...
# 10219  - **Primary Diagnosis:** Dependence on supplem...
#
#                                                     Plan
# 0      **Medication:**- Prescribe Vancomycin 125 mg, ...
# 1      - **Medications:** - Vancomycin 125 mg orally,...
# 2      **Treatment:**- Prescribe Fidaxomicin 200 mg o...
# 3      **Investigations/Test Results:**- Stool sample...
# 4      1. Enterocolitis due to Clostridium difficile-...
# ...                                                  ...
# 10215  - **Medications:** - Continue Albuterol inhale...
# 10216  - **Treatment Recommendations:** - Initiate su...
# 10217  Based on the current evaluation and pending di...
# 10218  s.**Review of Systems (ROS):**- **General:** R...
# 10219  1. **Continue Treatment:** - Maintain current ...
#
# [10220 rows x 8 columns]

# %%
def clean_asterisks(text):
    if not isinstance(text, str):
        return text
    # Match 3 or more leading asterisks and replace with exactly 2
    return re.sub(r'^\*{3,}', '**', text)

# Apply to the 4 SOAP columns
for col in ['Subjective', 'Objective', 'Assessment', 'Plan']:
    df[col] = df[col].apply(clean_asterisks)

df
# Out:
#                                                     Note  \
# 0      **1. Subjective:****Chief Complaint (CC):** Se...
# 1      **1. Subjective:****Chief Complaint (CC):**Fre...
# 2      **1. Subjective:****Chief Complaint (CC):**Mod...
# 3      **1. Subjective:****Chief Complaint (CC):**Wat...
# 4      **Subjective:****Chief Complaint (CC)**Severe ...
# ...                                                  ...
# 10215  **1. Subjective:****Chief Complaint (CC):**Fol...
# 10216  **1. Subjective:****Chief Complaint (CC):**Per...
# 10217  **1. Subjective:****Chief Complaint (CC):**Sev...
# 10218  **1. Subjective:****Chief Complaint (CC):**Sev...
# 10219  **1. Subjective:****Chief Complaint (CC):**Sev...
#
#                                                 Dialogue  ICD10  \
# 0      [doctor]: Good morning. How are you feeling to...   A047
# 1      [doctor]: Good morning, Mrs. Doe. How are you ...   A047
# 2      [doctor]: Hi Mr. Lee, how are you doing today?...   A047
# 3      [doctor]: Good morning, how are you today?[pat...   A047
# 4      [doctor]: Hi there, how are you doing today?[p...   A047
# ...                                                  ...    ...
# 10215  [doctor]: Good morning! It's nice to see you a...  Z9981
# 10216  ```markdown[doctor] Hello, how are you doing t...  Z9981
# 10217  [doctor] Good morning. How are you feeling tod...  Z9981
# 10218  [doctor] Hi Mr. Lee, how are you doing today?[...  Z9981
# 10219  [doctor]: Hi there, how are you feeling today?...  Z9981
#
#                                        ICD10_desc  \
# 0      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# 1      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# 2      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# 3      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# 4      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# ...                                           ...
# 10215           DEPENDENCE ON SUPPLEMENTAL OXYGEN
# 10216           DEPENDENCE ON SUPPLEMENTAL OXYGEN
# 10217           DEPENDENCE ON SUPPLEMENTAL OXYGEN
# 10218           DEPENDENCE ON SUPPLEMENTAL OXYGEN
# 10219           DEPENDENCE ON SUPPLEMENTAL OXYGEN
#
#                                               Subjective  \
# 0      **Chief Complaint (CC):** Severe abdominal pai...
# 1      **Chief Complaint (CC):**Frequent watery diarr...
# 2      **Chief Complaint (CC):**Moderate abdominal pa...
# 3      **Chief Complaint (CC):**Watery diarrhea and a...
# 4      **Chief Complaint (CC)**Severe abdominal cramp...
# ...                                                  ...
# 10215  **Chief Complaint (CC):**Follow-up for managem...
# 10216  **Chief Complaint (CC):**Persistent dry cough,...
# 10217  **Chief Complaint (CC):**Severe breathlessness...
# 10218  **Chief Complaint (CC):**Severe breathlessness...
# 10219  **Chief Complaint (CC):**Severe shortness of b...
#
#                                                Objective  \
# 0      **Vital Signs:**- Temperature: 100.8°F- Blood ...
# 1      **Vital Signs:**- Temperature: 100.5 °F- Blood...
# 2      This section is limited in a telemedicine enco...
# 3      - Physical Exam: Not applicable (telemedicine ...
# 4      **Vitals**- Temperature: 101.2 degrees F- Bloo...
# ...                                                  ...
# 10215  **Vital Signs:**- Blood Pressure: 138/82 mmHg-...
# 10216  **Physical Exam:**- **General:** Appears fatig...
# 10217  **Vital Signs:**- Blood Pressure: Not document...
# 10218  **Vital Signs:**- Blood Pressure: 140/85 mmHg-...
# 10219  **Vitals:**- BP: 130/85 mmHg- HR: 76 bpm- RR: ...
#
#                                               Assessment  \
# 0      **Diagnosis:** Enterocolitis due to Clostridiu...
# 1      - Enterocolitis due to Clostridium difficile (...
# 2      Diagnosis: Enterocolitis due to Clostridium di...
# 3      - Enterocolitis due to Clostridium difficile (...
# 4      1. Enterocolitis due to Clostridium difficile-...
# ...                                                  ...
# 10215  - **Chronic Obstructive Pulmonary Disease (COP...
# 10216  - Dependence on Supplemental Oxygen (ICD-10 Co...
# 10217  The patient presents with severe breathlessnes...
# 10218  - **Primary Diagnosis:** Dependence on Supplem...
# 10219  - **Primary Diagnosis:** Dependence on supplem...
#
#                                                     Plan
# 0      **Medication:**- Prescribe Vancomycin 125 mg, ...
# 1      - **Medications:** - Vancomycin 125 mg orally,...
# 2      **Treatment:**- Prescribe Fidaxomicin 200 mg o...
# 3      **Investigations/Test Results:**- Stool sample...
# 4      1. Enterocolitis due to Clostridium difficile-...
# ...                                                  ...
# 10215  - **Medications:** - Continue Albuterol inhale...
# 10216  - **Treatment Recommendations:** - Initiate su...
# 10217  Based on the current evaluation and pending di...
# 10218  s.**Review of Systems (ROS):**- **General:** R...
# 10219  1. **Continue Treatment:** - Maintain current ...
#
# [10220 rows x 8 columns]

# %%
# Determining under- and overrepresented ICD codes

counts = df['ICD10'].value_counts()
filtered = counts[counts != 5]

print(filtered)
# Out:
# ICD10
# E784       10
# E7849      10
# N10        10
# R312       10
# R3129      10
# R938       10
# R9389      10
# R972       10
# R9720      10
# Z9889      10
# Z98890     10
# B3781       4
# D473        4
# D485        4
# G893        4
# G894        4
# H4011X1     4
# I6350       4
# L97512      4
# M3214       4
# M4856XA     4
# N6320       4
# O621        4
# R42         4
# S0081XA     4
# S83512A     4
# S8991XA     4
# T82868A     4
# Z21         4
# Z793        4
# Z8616       4
# Name: count, dtype: int64

# %%
# Deleting rows with under- and overrepresented ICD codes

df = df[df['ICD10'].map(df['ICD10'].value_counts()) == 5]
df
# Out:
#                                                     Note  \
# 0      **1. Subjective:****Chief Complaint (CC):** Se...
# 1      **1. Subjective:****Chief Complaint (CC):**Fre...
# 2      **1. Subjective:****Chief Complaint (CC):**Mod...
# 3      **1. Subjective:****Chief Complaint (CC):**Wat...
# 4      **Subjective:****Chief Complaint (CC)**Severe ...
# ...                                                  ...
# 10215  **1. Subjective:****Chief Complaint (CC):**Fol...
# 10216  **1. Subjective:****Chief Complaint (CC):**Per...
# 10217  **1. Subjective:****Chief Complaint (CC):**Sev...
# 10218  **1. Subjective:****Chief Complaint (CC):**Sev...
# 10219  **1. Subjective:****Chief Complaint (CC):**Sev...
#
#                                                 Dialogue  ICD10  \
# 0      [doctor]: Good morning. How are you feeling to...   A047
# 1      [doctor]: Good morning, Mrs. Doe. How are you ...   A047
# 2      [doctor]: Hi Mr. Lee, how are you doing today?...   A047
# 3      [doctor]: Good morning, how are you today?[pat...   A047
# 4      [doctor]: Hi there, how are you doing today?[p...   A047
# ...                                                  ...    ...
# 10215  [doctor]: Good morning! It's nice to see you a...  Z9981
# 10216  ```markdown[doctor] Hello, how are you doing t...  Z9981
# 10217  [doctor] Good morning. How are you feeling tod...  Z9981
# 10218  [doctor] Hi Mr. Lee, how are you doing today?[...  Z9981
# 10219  [doctor]: Hi there, how are you feeling today?...  Z9981
#
#                                        ICD10_desc  \
# 0      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# 1      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# 2      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# 3      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# 4      ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# ...                                           ...
# 10215           DEPENDENCE ON SUPPLEMENTAL OXYGEN
# 10216           DEPENDENCE ON SUPPLEMENTAL OXYGEN
# 10217           DEPENDENCE ON SUPPLEMENTAL OXYGEN
# 10218           DEPENDENCE ON SUPPLEMENTAL OXYGEN
# 10219           DEPENDENCE ON SUPPLEMENTAL OXYGEN
#
#                                               Subjective  \
# 0      **Chief Complaint (CC):** Severe abdominal pai...
# 1      **Chief Complaint (CC):**Frequent watery diarr...
# 2      **Chief Complaint (CC):**Moderate abdominal pa...
# 3      **Chief Complaint (CC):**Watery diarrhea and a...
# 4      **Chief Complaint (CC)**Severe abdominal cramp...
# ...                                                  ...
# 10215  **Chief Complaint (CC):**Follow-up for managem...
# 10216  **Chief Complaint (CC):**Persistent dry cough,...
# 10217  **Chief Complaint (CC):**Severe breathlessness...
# 10218  **Chief Complaint (CC):**Severe breathlessness...
# 10219  **Chief Complaint (CC):**Severe shortness of b...
#
#                                                Objective  \
# 0      **Vital Signs:**- Temperature: 100.8°F- Blood ...
# 1      **Vital Signs:**- Temperature: 100.5 °F- Blood...
# 2      This section is limited in a telemedicine enco...
# 3      - Physical Exam: Not applicable (telemedicine ...
# 4      **Vitals**- Temperature: 101.2 degrees F- Bloo...
# ...                                                  ...
# 10215  **Vital Signs:**- Blood Pressure: 138/82 mmHg-...
# 10216  **Physical Exam:**- **General:** Appears fatig...
# 10217  **Vital Signs:**- Blood Pressure: Not document...
# 10218  **Vital Signs:**- Blood Pressure: 140/85 mmHg-...
# 10219  **Vitals:**- BP: 130/85 mmHg- HR: 76 bpm- RR: ...
#
#                                               Assessment  \
# 0      **Diagnosis:** Enterocolitis due to Clostridiu...
# 1      - Enterocolitis due to Clostridium difficile (...
# 2      Diagnosis: Enterocolitis due to Clostridium di...
# 3      - Enterocolitis due to Clostridium difficile (...
# 4      1. Enterocolitis due to Clostridium difficile-...
# ...                                                  ...
# 10215  - **Chronic Obstructive Pulmonary Disease (COP...
# 10216  - Dependence on Supplemental Oxygen (ICD-10 Co...
# 10217  The patient presents with severe breathlessnes...
# 10218  - **Primary Diagnosis:** Dependence on Supplem...
# 10219  - **Primary Diagnosis:** Dependence on supplem...
#
#                                                     Plan
# 0      **Medication:**- Prescribe Vancomycin 125 mg, ...
# 1      - **Medications:** - Vancomycin 125 mg orally,...
# 2      **Treatment:**- Prescribe Fidaxomicin 200 mg o...
# 3      **Investigations/Test Results:**- Stool sample...
# 4      1. Enterocolitis due to Clostridium difficile-...
# ...                                                  ...
# 10215  - **Medications:** - Continue Albuterol inhale...
# 10216  - **Treatment Recommendations:** - Initiate su...
# 10217  Based on the current evaluation and pending di...
# 10218  s.**Review of Systems (ROS):**- **General:** R...
# 10219  1. **Continue Treatment:** - Maintain current ...
#
# [10030 rows x 8 columns]

# %%
# UMAP exploration - 2D embedding of SOAP notes by ICD-10 class

import subprocess, importlib
for pkg in ["scikit-learn", "umap-learn"]:
    mod = "sklearn" if pkg == "scikit-learn" else "umap"
    try:
        importlib.import_module(mod)
    except ModuleNotFoundError:
        subprocess.check_call(["pip", "install", "-q", pkg])

from sklearn.feature_extraction.text import TfidfVectorizer
from umap import UMAP
import matplotlib.pyplot as plt
import numpy as np

# TF-IDF on the full SOAP notes
vectorizer = TfidfVectorizer(max_features=5000, stop_words="english")
tfidf = vectorizer.fit_transform(df["Note"].fillna(""))

# UMAP â†’ 2D
reducer = UMAP(n_components=2, random_state=0, n_neighbors=15, min_dist=0.1)
coords = reducer.fit_transform(tfidf)

# Per-class centroids
df["_ux"], df["_uy"] = coords[:, 0], coords[:, 1]
centroids = df.groupby("ICD10").agg(_ux=("_ux", "mean"), _uy=("_uy", "mean")).reset_index()
centroids["chapter"] = centroids["ICD10"].str[0]
df.drop(columns=["_ux", "_uy"], inplace=True)

# ICD-10 chapter labels
ICD_CHAPTERS = {
    "A": "A - Infectious", "B": "B - Infectious", "C": "C - Neoplasms",
    "D": "D - Blood/Immune", "E": "E - Endocrine", "F": "F - Mental",
    "G": "G - Nervous", "H": "H - Eye/Ear", "I": "I - Circulatory",
    "J": "J - Respiratory", "K": "K - Digestive", "L": "L - Skin",
    "M": "M - Musculoskeletal", "N": "N - Genitourinary", "O": "O - Pregnancy",
    "P": "P - Perinatal", "Q": "Q - Congenital", "R": "R - Symptoms",
    "S": "S - Injury", "T": "T - Injury/Poisoning", "U": "U - Special",
    "V": "V - External", "W": "W - External", "X": "X - External",
    "Y": "Y - External", "Z": "Z - Health factors",
}

chapters = sorted(centroids["chapter"].unique())
cmap = plt.cm.get_cmap("tab20", len(chapters))

fig, ax = plt.subplots(figsize=(14, 9), dpi=150)
for i, ch in enumerate(chapters):
    sub = centroids[centroids["chapter"] == ch]
    ax.scatter(sub["_ux"], sub["_uy"], c=[cmap(i)], s=18, alpha=0.7,
               label=ICD_CHAPTERS.get(ch, ch))

ax.set_xlabel("UMAP 1")
ax.set_ylabel("UMAP 2")
ax.set_title(f"UMAP - ICD-10 Class Centroids  (n = {len(centroids)} classes, TF-IDF on SOAP Notes)")
ax.legend(title="ICD-10 Chapter", bbox_to_anchor=(1.02, 1), loc="upper left",
          fontsize=8, title_fontsize=9, markerscale=1.5)
plt.tight_layout()
fig.savefig("umap_icd10_centroids.png", dpi=300, bbox_inches="tight")
plt.show()

print(f"Classes: {len(centroids)} | Observations: {len(df)} | Chapters: {len(chapters)}")
# Out:
# c:\Users\Keno\VSCode\Uni\HIMA_Research_Project\.venv\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# C:\Users\Keno\AppData\Local\Temp\ipykernel_4240\4088017736.py:44: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab20", len(chapters))
# Classes: 2006 | Observations: 10030 | Chapters: 22

# %%
# Train / Validation / Test split  (70 / 10 / 20)
SEED = 0

# Test set: 1 random sample per ICD class (~20%)
test_df = df.groupby('ICD10', group_keys=False).sample(n=1, random_state=SEED)

# Remaining 4 samples per class, randomly shuffled
remaining_df = df.drop(test_df.index).sample(frac=1, random_state=SEED).reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

# Validation: 10% of remaining (~8% of total)
val_idx = remaining_df.sample(frac=0.1, random_state=SEED).index
val_df = remaining_df.loc[val_idx].reset_index(drop=True)

# Training: remaining 90% (~72% of total)
train_df = remaining_df.drop(val_idx).reset_index(drop=True)

print(f'Train:      {len(train_df):>5} rows')
print(f'Validation: {len(val_df):>5} rows')
print(f'Test:       {len(test_df):>5} rows')
print(f'Total:      {len(train_df) + len(val_df) + len(test_df):>5} rows')
# Out:
# Train:       7222 rows
# Validation:   802 rows
# Test:        2006 rows
# Total:      10030 rows

# %%
train_df
# Out:
#                                                    Note  \
# 0     **1. Subjective:****Chief Complaint (CC):**55-...
# 1     **Constitutional**: Denies fever, weight loss,...
# 2     **1. Subjective:****Chief Complaint (CC):**Sev...
# 3     **1. Subjective:****Chief Complaint:**- Patien...
# 4     **Chief Complaint (CC):**- Moderate to severe ...
# ...                                                 ...
# 7217  **1. Subjective:****Chief Complaint (CC):**Rig...
# 7218  **Chief Complaint (CC):**Persistent knee pain....
# 7219  **Subjective:****Chief Complaint (CC):**Persis...
# 7220  **1. Subjective:****Chief Complaint (CC):**Sei...
# 7221  **1. Subjective:****Chief Complaint (CC):**Sev...
#
#                                                Dialogue   ICD10  \
# 0     [doctor]: Good morning! How are you feeling to...    E210
# 1     [doctor] Hello, it's nice to meet you today. H...   I5043
# 2     [doctor]: Hi Mr. Duncan, it’s good to see you ...   M5410
# 3     [doctor] Hi, how are you today?[patient] Hi, I...   F1210
# 4     [doctor] Hi there, how are you doing today?[pa...    K862
# ...                                                 ...     ...
# 7217  [doctor] Hi there, how are you doing today?[pa...   R1031
# 7218  **Doctor:** Hello, good to see you today. What...   M7989
# 7219  [doctor] Good morning, how are you doing today...   M9905
# 7220  [doctor]: Hi, how are you today?[patient]: Hi,...   G4089
# 7221  [doctor]: Hi Ms. Thompson, how are you feeling...  I82412
#
#                                              ICD10_desc  \
# 0                           PRIMARY HYPERPARATHYROIDISM
# 1     ACUTE ON CHRONIC COMBINED SYSTOLIC (CONGESTIVE...
# 2                       RADICULOPATHY, SITE UNSPECIFIED
# 3                         CANNABIS ABUSE, UNCOMPLICATED
# 4                                      CYST OF PANCREAS
# ...                                                 ...
# 7217                          RIGHT LOWER QUADRANT PAIN
# 7218              OTHER SPECIFIED SOFT TISSUE DISORDERS
# 7219  SEGMENTAL AND SOMATIC DYSFUNCTION OF PELVIC RE...
# 7220                                     OTHER SEIZURES
# 7221  ACUTE EMBOLISM AND THROMBOSIS OF LEFT FEMORAL ...
#
#                                              Subjective  \
# 0     **Chief Complaint (CC):**55-year-old female pr...
# 1     **Constitutional**: Denies fever, weight loss,...
# 2     **Chief Complaint (CC):**Severe radiating pain...
# 3     **Chief Complaint:**- Patient reports signific...
# 4     - Moderate to severe epigastric pain.**History...
# ...                                                 ...
# 7217  **Chief Complaint (CC):**Right lower quadrant ...
# 7218  Persistent knee pain.**History of Present Illn...
# 7219  **Chief Complaint (CC):**Persistent cough.**Hi...
# 7220  **Chief Complaint (CC):**Seizures occurring 2-...
# 7221  **Chief Complaint (CC):**Severe pain and inabi...
#
#                                               Objective  \
# 0     - **Vital Signs:** - Blood Pressure: 130/80 mm...
# 1     #### Physical Examination- **Vital Signs**: BP...
# 2     **Vital Signs:**- Blood Pressure: 135/85 mmHg-...
# 3     **Physical Exam:**- General: Appears dishevele...
# 4     Vital Signs:**- BP: 122/78 mmHg- HR: 78 bpm- R...
# ...                                                 ...
# 7217  **Vital Signs:**- Blood Pressure: 120/75 mmHg-...
# 7218  Vital Signs:**- BP: 128/82 mmHg- HR: 72 bpm- R...
# 7219  **Vital Signs:**- Temperature: 98.6°F- Blood P...
# 7220  **Vital Signs:**- Blood pressure: 118/76 mmHg-...
# 7221  **General:**Appears frail, in distress.**Vital...
#
#                                              Assessment  \
# 0                         - Primary Hyperparathyroidism
# 1     The patient is a 27-year-old male with a histo...
# 2     - **Primary Diagnosis:** Radiculopathy, Site U...
# 3     - Cannabis Abuse, Uncomplicated (F12.10)- Co-o...
# 4     Diagnosis:**- Cyst of Pancreas (ICD-10 Code: K...
# ...                                                 ...
# 7217  The patient is a 35-year-old female presenting...
# 7218  - **Diagnosis:** Other Specified Soft Tissue D...
# 7219  The patient is a 30-year-old male diagnosed wi...
# 7220  **Diagnosis:** Other Seizures (ICD-10 Code: G4...
# 7221  - **Diagnosis:** Acute embolism and thrombosis...
#
#                                                    Plan
# 0     - **Surgical Referral:** Referred to Dr. Susan...
# 1     1. **Asthma Management**: - Continue Albuterol...
# 2     - **Medication:** Prescribed Tramadol 50 mg or...
# 3     - **Treatment:** - Enroll in a Dual Diagnosis ...
# 4     Treatment Recommendations:**- Observation with...
# ...                                                 ...
# 7217  **Medical Treatment:**- Prescribe Acetaminophe...
# 7218  - **Treatment**: - Referral to acupuncture ses...
# 7219  - **Medication:** Azithromycin 500 mg on day 1...
# 7220  - **Medical Treatment:** Start Levetiracetam 5...
# 7221  **Treatment:**- Initiate thrombolytic therapy ...
#
# [7222 rows x 8 columns]

# %%
val_df
# Out:
#                                                   Note  \
# 0    **1. Subjective:****Chief Complaint (CC):**Sev...
# 1    **1. Subjective:****Chief Complaint (CC):**Rig...
# 2    **Subjective:**- **Chief Complaint (CC):** Fol...
# 3    **1. Subjective:****Chief Complaint (CC):**Blu...
# 4    **1. Subjective:****Chief Complaint (CC):**Unu...
# ..                                                 ...
# 797  **1. Subjective:** - Chief Complaint (CC): Pos...
# 798  **1. Subjective:****Chief Complaint (CC):**- I...
# 799  **Chief Complaint (CC):**- Severe headaches wi...
# 800  **1. Subjective:****Chief Complaint (CC):** Pe...
# 801  **1. Subjective:****Chief Complaint (CC):**The...
#
#                                               Dialogue   ICD10  \
# 0    [doctor]: Good morning, John. How are you feel...    R091
# 1    [doctor]: Hi Mr. Doe, how are you today?[patie...  M75101
# 2    [doctor] Good morning, how are you feeling tod...   C9201
# 3    [doctor]: Hello Mr. Gomez, how are you doing t...   H1033
# 4    [doctor]: Good morning, Mr. Rodríguez. How are...   R8299
# ..                                                 ...     ...
# 797  [doctor]: Hello, how are you today?[patient]: ...   Z9884
# 798  [doctor]: Good morning! How are you doing toda...    N978
# 799  [doctor] Hi there, how are you doing today?[pa...   G4489
# 800  [doctor] Hi, how are you doing today?[patient]...    J209
# 801  [doctor]: Good afternoon, how are you doing to...    Z905
#
#                                             ICD10_desc  \
# 0                                             PLEURISY
# 1    UNSPECIFIED ROTATOR CUFF TEAR OR RUPTURE OF RI...
# 2            ACUTE MYELOBLASTIC LEUKEMIA, IN REMISSION
# 3          UNSPECIFIED ACUTE CONJUNCTIVITIS, BILATERAL
# 4                     OTHER ABNORMAL FINDINGS IN URINE
# ..                                                 ...
# 797                           BARIATRIC SURGERY STATUS
# 798                 FEMALE INFERTILITY OF OTHER ORIGIN
# 799                            OTHER HEADACHE SYNDROME
# 800                      ACUTE BRONCHITIS, UNSPECIFIED
# 801                         ACQUIRED ABSENCE OF KIDNEY
#
#                                             Subjective  \
# 0    **Chief Complaint (CC):**Severe chest pain, du...
# 1    **Chief Complaint (CC):**Right shoulder pain.*...
# 2    - **Chief Complaint (CC):** Follow-up visit fo...
# 3    **Chief Complaint (CC):**Blurred vision and di...
# 4    **Chief Complaint (CC):**Unusual urine color a...
# ..                                                 ...
# 797  - Chief Complaint (CC): Post-operative follow-...
# 798  **Chief Complaint (CC):**- Infertility evaluat...
# 799  - Severe headaches with nausea, vomiting, phot...
# 800  **Chief Complaint (CC):** Persistent cough, so...
# 801  **Chief Complaint (CC):**The patient, a 64-yea...
#
#                                              Objective  \
# 0    **Vital Signs:**- BP: 128/76 mmHg- HR: 92 bpm-...
# 1    **Vital Signs:**- Blood Pressure: 130/80 mmHg-...
# 2    - **Vital Signs:** - Blood Pressure: 145/88 mm...
# 3    **Vital Signs:**- Blood Pressure: 140/90 mmHg-...
# 4    **Vital Signs:**- Blood Pressure (BP): 130/75 ...
# ..                                                 ...
# 797  - Vital Signs: - Blood Pressure: 128/82 mmHg -...
# 798  **Vital Signs:**- Temperature: 98.6°F- Blood P...
# 799  - **Vital Signs:** Within normal limits.- **Ge...
# 800  **Vital Signs:**- Temp: 38°C- HR: 85 bpm- RR: ...
# 801  **Vital Signs:**- BP: 160/95 mmHg- HR: 78 bpm*...
#
#                                             Assessment  \
# 0    John Martinez is a 35-year-old male presenting...
# 1    **Primary Diagnosis:**Unspecified rotator cuff...
# 2    1. **Acute Myeloblastic Leukemia, in remission...
# 3    **Diagnosis:**1. **Type 2 Diabetes Mellitus:**...
# 4    Mr. Juan Rodríguez is a 24-year-old male prese...
# ..                                                 ...
# 797  - Post-operative status following bariatric su...
# 798  - Primary Diagnosis: Female infertility of oth...
# 799  - **Primary Diagnosis:** Other headache syndro...
# 800      **Diagnosis:** Acute Bronchitis, unspecified.
# 801  - Acquired absence of kidney.- Moderate hypert...
#
#                                                   Plan
# 0    1. **NSAIDs:** - Ibuprofen 600 mg, oral, three...
# 1    - **Medications:** - Methocarbamol 750 mg, ora...
# 2    1. **Acute Myeloblastic Leukemia:** - **Monito...
# 3    **Medical Treatment:**- **Metformin** 500 mg o...
# 4    **Investigations:**- Urinalysis: Awaiting resu...
# ..                                                 ...
# 797  - Continue adherence to post-surgical nutritio...
# 798  **Medical Treatment:**- Initiate Clomiphene ci...
# 799  1. **Medical Treatment:** - Initiate Gabapenti...
# 800  **Treatment Recommendations:**- **Bronchodilat...
# 801  **Medication Adjustment:**- Prescribe Lisinopr...
#
# [802 rows x 8 columns]

# %%
test_df
# Out:
#                                                    Note  \
# 0     **1. Subjective:****Chief Complaint (CC):**Mod...
# 1     **1. Subjective:****Chief Complaint (CC):** Wa...
# 2     **1. Subjective:****Chief Complaint (CC):**Sev...
# 3     **1. Subjective:****Chief Complaint (CC):**Sev...
# 4     **SUBJECTIVE:****Chief Complaint (CC):**Headac...
# ...                                                 ...
# 2001  **1. Subjective:** **Chief Complaint (CC):** -...
# 2002  **1. Subjective:****Chief Complaint (CC):**Mil...
# 2003  **1. Subjective:****Chief Complaint (CC):**Fol...
# 2004  **Subjective:****Chief Complaint (CC):**Fatigu...
# 2005  **1. Subjective:****Chief Complaint (CC):**Per...
#
#                                                Dialogue  ICD10  \
# 0     [doctor]: Hi Mr. Lee, how are you doing today?...   A047
# 1     [doctor]: Hi Jane, I see you’re here today bec...  A0472
# 2     [doctor] Good morning, how are you feeling tod...   A084
# 3     [doctor] Hi Ms. Williams, how are you today?[p...    A09
# 4     [doctor] Hi Maria, how are you doing today?[pa...  A4101
# ...                                                 ...    ...
# 2001  [doctor]: Hello, it's nice to meet you. I see ...  Z9861
# 2002  [doctor] Hi Maria, how are you feeling today?[...  Z9884
# 2003  [doctor] Good morning, John. How are you feeli...  Z9911
# 2004  [doctor]: Hi there, I see you're here today fo...   Z992
# 2005  ```markdown[doctor] Hello, how are you doing t...  Z9981
#
#                                              ICD10_desc  \
# 0            ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE
# 1     ENTEROCOLITIS DUE TO CLOSTRIDIUM DIFFICILE, NO...
# 2               VIRAL INTESTINAL INFECTION, UNSPECIFIED
# 3     INFECTIOUS GASTROENTERITIS AND COLITIS, UNSPEC...
# 4     SEPSIS DUE TO METHICILLIN SUSCEPTIBLE STAPHYLO...
# ...                                                 ...
# 2001                        CORONARY ANGIOPLASTY STATUS
# 2002                           BARIATRIC SURGERY STATUS
# 2003       DEPENDENCE ON RESPIRATOR [VENTILATOR] STATUS
# 2004                       DEPENDENCE ON RENAL DIALYSIS
# 2005                  DEPENDENCE ON SUPPLEMENTAL OXYGEN
#
#                                              Subjective  \
# 0     **Chief Complaint (CC):**Moderate abdominal pa...
# 1     **Chief Complaint (CC):** Watery diarrhea, abd...
# 2     **Chief Complaint (CC):**Severe abdominal cram...
# 3     **Chief Complaint (CC):**Severe abdominal cram...
# 4     **Chief Complaint (CC):**Headache, neck stiffn...
# ...                                                 ...
# 2001  **Chief Complaint (CC):** - The patient report...
# 2002  **Chief Complaint (CC):**Mild abdominal discom...
# 2003  **Chief Complaint (CC):**Follow-up for ventila...
# 2004  **Chief Complaint (CC):**Fatigue and muscle cr...
# 2005  **Chief Complaint (CC):**Persistent dry cough,...
#
#                                               Objective  \
# 0     This section is limited in a telemedicine enco...
# 1     **VITALS:**- BP: 125/82 mmHg- HR: 90 bpm- Temp...
# 2     **Vital Signs:**- Temperature: Low-grade fever...
# 3     **Physical Examination:**- **General:** Appear...
# 4     **Vital Signs:**- Temperature: 38.1°C- Heart R...
# ...                                                 ...
# 2001  **Vital Signs:** - Blood Pressure: 135/85 mmHg...
# 2002  **Vital Signs:**- Blood Pressure: 130/85 mmHg-...
# 2003  **Physical Examination:**- **Respiratory:** Au...
# 2004  - **Vital Signs:** Blood pressure: 140/85 mmHg...
# 2005  **Physical Exam:**- **General:** Appears fatig...
#
#                                              Assessment  \
# 0     Diagnosis: Enterocolitis due to Clostridium di...
# 1     Enterocolitis due to Clostridium difficile, no...
# 2     **Primary Diagnosis:**- Viral Intestinal Infec...
# 3     Ms. Lisa Williams is a 32-year-old female with...
# 4     Viral meningitis, likely secondary to Enterovi...
# ...                                                 ...
# 2001  - The patient is a 72-year-old male with a rec...
# 2002  Maria Gonzalez is a 45-year-old female with a ...
# 2003  John Anderson is a 68-year-old male with a his...
# 2004  1. **Dependence on Renal Dialysis (ICD-10 Z99....
# 2005  - Dependence on Supplemental Oxygen (ICD-10 Co...
#
#                                                    Plan
# 0     **Treatment:**- Prescribe Fidaxomicin 200 mg o...
# 1     - **Medications:** - Prescribed Vancomycin, 12...
# 2     1. **Medical Treatment:** - **Oral rehydration...
# 3     **Diagnosis:** Infectious gastroenteritis and ...
# 4     1. **Antiviral Therapy:** - Acyclovir 10 mg/kg...
# ...                                                 ...
# 2001  s to start light aerobic exercise; consumes al...
# 2002  - **Testing:** - Blood Work: Ordered biochemis...
# 2003  1. **Adjust Ventilator Settings:** - Modify ve...
# 2004  1. **Dependence on Renal Dialysis:** - Continu...
# 2005  - **Treatment Recommendations:** - Initiate su...
#
# [2006 rows x 8 columns]

# %%
# Preparing data for Single LLM finetuning

def format_training_example(dialogue: str, note: str, icd10: str, icd10_desc: str):
    system_prompt = """You are a medical documentation assistant. Your task is to convert patient-doctor consultation dialogues into structured SOAP notes (Subjective, Objective, Assessment, Plan) with appropriate ICD-10 diagnosis codes.

Generate a comprehensive SOAP note that includes:
1. Subjective: Chief complaint, history of present illness, review of systems
2. Objective: Vital signs, physical examination findings
3. Assessment: Diagnosis with ICD-10 code and description, differential diagnoses
4. Plan: Management, referrals, further testing, patient education

Stick to the following rules with absolute authority:
- Do not include anything into the SOAP note that is not present in the presented dialogue.
- Do not assume anything. Be deterministic and only take what is named in the text.
- If you cannot fill out something in the SOAP notes, write only [UNKNOWN] to the corresponding dimension or subdimension.
"""

    user_prompt = f"""Convert the following patient-doctor consultation dialogue into a structured SOAP note:

{dialogue}"""

    # Include ICD10 in the assistant response
    assistant_response = f"""{note}

**ICD-10 Code:** {icd10}
**Diagnosis:** {icd10_desc}"""

    return {
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt},
            {"role": "assistant", "content": assistant_response}
        ]
    }


def process_json_file(input_dataframe: object, output_file_name: str):
    data_records = []
    for idx in range(len(input_dataframe)):
        dialogue = input_dataframe['Dialogue'][idx]
        note = input_dataframe['Note'][idx]
        icd10 = input_dataframe['ICD10'][idx]
        icd10_desc = input_dataframe['ICD10_desc'][idx]

        formatted_example = format_training_example(dialogue, note, icd10, icd10_desc)
        data_records.append(formatted_example)

    # Save to JSONL format
    with open(output_file_name, 'w', encoding='utf-8') as f:
        for record in data_records:
            f.write(json.dumps(record, ensure_ascii=False) + '\n')

single_train_df = train_df.drop(["Subjective", "Objective", "Assessment", "Plan"], axis=1)
single_val_df   = val_df.drop(["Subjective", "Objective", "Assessment", "Plan"], axis=1)
single_test_df  = test_df.drop(["Subjective", "Objective", "Assessment", "Plan"], axis=1)

os.makedirs("single_agent/data/test",       exist_ok=True)
os.makedirs("baseline/data/test",           exist_ok=True)

process_json_file(single_train_df, "single_agent/data/training_single.jsonl")
process_json_file(single_val_df,   "single_agent/data/validation_single.jsonl")

# Test files (held-out test set, full SOAP format)
process_json_file(single_test_df, "single_agent/data/test/test_full.jsonl")
process_json_file(single_test_df, "multi_agents/data/test/test_full.jsonl")
process_json_file(single_test_df, "swarm_agents/data/test/test_full.jsonl")
process_json_file(single_test_df, "baseline/data/test/test_full.jsonl")

# %%
# Preparing data for Multi-Agent finetuning (per SOAP dimension)

SOAP_CONFIGS = {
    "subjective": {
        "column": "Subjective",
        "system_prompt": """You are a medical documentation assistant specializing in the Subjective section of SOAP notes. Your task is to extract the Subjective component from a patient-doctor consultation dialogue.

Generate a Subjective section that includes:
- Chief Complaint (CC)
- History of Present Illness (HPI)
- Review of Systems (ROS)
- Past Medical History, Family History, Social History where mentioned

Stick to the following rules with absolute authority:
- Do not include anything that is not present in the presented dialogue.
- Do not assume anything. Be deterministic and only take what is named in the text.
- If you cannot fill out a subdimension, write only [UNKNOWN] for that subdimension."""
    },
    "objective": {
        "column": "Objective",
        "system_prompt": """You are a medical documentation assistant specializing in the Objective section of SOAP notes. Your task is to extract the Objective component from a patient-doctor consultation dialogue.

Generate an Objective section that includes:
- Vital Signs
- Physical Examination findings
- Laboratory and diagnostic test results where mentioned

Stick to the following rules with absolute authority:
- Do not include anything that is not present in the presented dialogue.
- Do not assume anything. Be deterministic and only take what is named in the text.
- If you cannot fill out a subdimension, write only [UNKNOWN] for that subdimension."""
    },
    "assessment": {
        "column": "Assessment",
        "system_prompt": """You are a medical documentation assistant specializing in the Assessment section of SOAP notes. Your task is to extract the Assessment component from a patient-doctor consultation dialogue.

Generate an Assessment section that includes:
- Primary diagnosis with ICD-10 code and description
- Differential diagnoses where discussed
- Clinical reasoning and justification

Stick to the following rules with absolute authority:
- Do not include anything that is not present in the presented dialogue.
- Do not assume anything. Be deterministic and only take what is named in the text.
- If you cannot fill out a subdimension, write only [UNKNOWN] for that subdimension."""
    },
    "plan": {
        "column": "Plan",
        "system_prompt": """You are a medical documentation assistant specializing in the Plan section of SOAP notes. Your task is to extract the Plan component from a patient-doctor consultation dialogue.

Generate a Plan section that includes:
- Medications and treatments
- Referrals and follow-up appointments
- Further testing or investigations
- Patient education and instructions

Stick to the following rules with absolute authority:
- Do not include anything that is not present in the presented dialogue.
- Do not assume anything. Be deterministic and only take what is named in the text.
- If you cannot fill out a subdimension, write only [UNKNOWN] for that subdimension."""
    },
}


def format_soap_example(dialogue: str, soap_text: str, dimension: str):
    config = SOAP_CONFIGS[dimension]
    return {
        "messages": [
            {"role": "system", "content": config["system_prompt"]},
            {"role": "user", "content": f"Extract the {dimension.capitalize()} section from the following patient-doctor consultation dialogue:\n\n{dialogue}"},
            {"role": "assistant", "content": soap_text},
        ]
    }


def process_soap_dimension(df: pd.DataFrame, dimension: str, output_file: str):
    col = SOAP_CONFIGS[dimension]["column"]
    records = []
    for idx in range(len(df)):
        dialogue = df["Dialogue"].iloc[idx]
        soap_text = df[col].iloc[idx]
        if not isinstance(soap_text, str) or soap_text.strip() == "":
            continue
        records.append(format_soap_example(dialogue, soap_text, dimension))

    with open(output_file, "w", encoding="utf-8") as f:
        for rec in records:
            f.write(json.dumps(rec, ensure_ascii=False) + "\n")

    print(f"{dimension}: wrote {len(records)} examples to {output_file}")


multi_train_df = train_df.drop(["Note"], axis=1)
multi_val_df   = val_df.drop(["Note"], axis=1)
multi_test_df  = test_df.drop(["Note"], axis=1)

os.makedirs("multi_agents/data/test",       exist_ok=True)

for dim in SOAP_CONFIGS:
    process_soap_dimension(multi_train_df, dim, f"multi_agents/data/training/training_{dim}.jsonl")
    process_soap_dimension(multi_val_df,   dim, f"multi_agents/data/validation/validation_{dim}.jsonl")
    process_soap_dimension(multi_test_df,  dim, f"multi_agents/data/test/test_{dim}.jsonl")
# Out:
# subjective: wrote 7222 examples to multi_agents/data/training/training_subjective.jsonl
# subjective: wrote 802 examples to multi_agents/data/validation/validation_subjective.jsonl
# subjective: wrote 2006 examples to multi_agents/data/test/test_subjective.jsonl
# objective: wrote 7222 examples to multi_agents/data/training/training_objective.jsonl
# objective: wrote 802 examples to multi_agents/data/validation/validation_objective.jsonl
# objective: wrote 2006 examples to multi_agents/data/test/test_objective.jsonl
# assessment: wrote 7222 examples to multi_agents/data/training/training_assessment.jsonl
# assessment: wrote 802 examples to multi_agents/data/validation/validation_assessment.jsonl
# assessment: wrote 2006 examples to multi_agents/data/test/test_assessment.jsonl
# plan: wrote 7222 examples to multi_agents/data/training/training_plan.jsonl
# plan: wrote 802 examples to multi_agents/data/validation/validation_plan.jsonl
# plan: wrote 2006 examples to multi_agents/data/test/test_plan.jsonl

# %%
"""
Preparing data for Swarm Agent finetuning (Draft-Critique-Refine per SOAP dimension)

Architecture: 3 agents per SOAP dimension x 4 dimensions = 12 fine-tuned adapters
  Drafter  ->  extracts initial SOAP section from the consultation dialogue
  Critic   ->  reviews the draft against the source dialogue, identifies issues
  Refiner  ->  integrates critique feedback into a definitive final section

Training data for the Critic and Refiner is bootstrapped via ICD-code
cross-pairing: each sample is paired with a different example that shares the
same ICD code, whose SOAP section serves as a synthetic "imperfect draft".
Programmatic critiques are then generated by comparing draft tokens against
the gold standard and the source dialogue.  These synthetic critiques are
approximate -- their primary purpose is to teach the model the critique *format*
and *task*; the fine-tuned model's pre-trained reasoning will refine quality.
"""

import random
from collections import defaultdict

# --- Dimension configurations --------------------------------------------------

SWARM_DIMS = {
    "subjective": {
        "column": "Subjective",
        "includes": (
            "- Chief Complaint (CC)\n"
            "- History of Present Illness (HPI)\n"
            "- Review of Systems (ROS)\n"
            "- Past Medical History, Family History, Social History where mentioned"
        ),
    },
    "objective": {
        "column": "Objective",
        "includes": (
            "- Vital Signs\n"
            "- Physical Examination findings\n"
            "- Laboratory and diagnostic test results where mentioned"
        ),
    },
    "assessment": {
        "column": "Assessment",
        "includes": (
            "- Primary diagnosis with ICD-10 code and description\n"
            "- Differential diagnoses where discussed\n"
            "- Clinical reasoning and justification"
        ),
    },
    "plan": {
        "column": "Plan",
        "includes": (
            "- Medications and treatments\n"
            "- Referrals and follow-up appointments\n"
            "- Further testing or investigations\n"
            "- Patient education and instructions"
        ),
    },
}

RULES_BLOCK = (
    "Stick to the following rules with absolute authority:\n"
    "- Do not include anything that is not present in the presented dialogue.\n"
    "- Do not assume anything. Be deterministic and only take what is named in the text.\n"
    "- If you cannot fill out a subdimension, write only [UNKNOWN] for that subdimension."
)


# --- System-prompt builders ----------------------------------------------------

def drafter_system(dim):
    d = SWARM_DIMS[dim]
    return (
        f"You are a medical documentation specialist responsible for drafting "
        f"the {dim.capitalize()} section of SOAP notes. Your task is to extract "
        f"and draft the {dim.capitalize()} component from a patient-doctor "
        f"consultation dialogue.\n\n"
        f"Generate a {dim.capitalize()} section that includes:\n"
        f"{d['includes']}\n\n"
        f"{RULES_BLOCK}"
    )


def critic_system(dim):
    return (
        f"You are a clinical documentation quality reviewer specializing in the "
        f"{dim.capitalize()} section of SOAP notes. Your task is to review a "
        f"draft against the source patient-doctor consultation dialogue and "
        f"provide a structured critique.\n\n"
        f"Evaluate the draft for:\n"
        f"1. HALLUCINATIONS: Information in the draft NOT supported by the dialogue\n"
        f"2. OMISSIONS: Key information from the dialogue MISSING in the draft\n"
        f"3. CLINICAL ACCURACY: Incorrect medical terminology or reasoning\n"
        f"4. FORMATTING: Structure and completeness issues\n\n"
        f"For each category, list specific findings. If no issues are found in a "
        f"category, state \"None identified.\"\n"
        f"End with VERDICT: GOOD | NEEDS_REVISION | POOR"
    )


def refiner_system(dim):
    return (
        f"You are a clinical documentation specialist performing final revision "
        f"of the {dim.capitalize()} section of SOAP notes. Given the source "
        f"consultation dialogue, an initial draft, and a peer critique, produce "
        f"the definitive {dim.capitalize()} section.\n\n"
        f"Incorporate the critique feedback to:\n"
        f"- Remove any hallucinated information not supported by the dialogue\n"
        f"- Add identified omissions from the dialogue\n"
        f"- Correct clinical terminology where needed\n"
        f"- Ensure proper structure and formatting\n\n"
        f"{RULES_BLOCK}"
    )


# --- Cross-pairing for synthetic imperfect drafts -----------------------------

def build_cross_pairs(df):
    """Pair each row with another row sharing the same ICD-10 code (circular
    shift within each code group).  Singletons are randomly paired with one
    another as a fallback."""
    icd_groups = defaultdict(list)
    for idx in range(len(df)):
        icd_groups[df["ICD10"].iloc[idx]].append(idx)

    pairs = []
    singletons = []

    for indices in icd_groups.values():
        if len(indices) < 2:
            singletons.extend(indices)
            continue
        for i, idx in enumerate(indices):
            pairs.append((idx, indices[(i + 1) % len(indices)]))

    # Fallback: pair singletons with each other
    random.shuffle(singletons)
    for i in range(0, len(singletons) - 1, 2):
        pairs.append((singletons[i], singletons[i + 1]))
        pairs.append((singletons[i + 1], singletons[i]))

    return pairs


# --- Synthetic critique generation ---------------------------------------------

def _medical_tokens(text):
    """Extract tokens likely to carry clinical or factual meaning."""
    toks = set(re.findall(r"\b[\w./-]+\b", text.lower()))
    return {t for t in toks if len(t) > 3 or any(c.isdigit() for c in t)}


def generate_synthetic_critique(dialogue, draft, gold, dim):
    draft_tok = _medical_tokens(draft)
    gold_tok  = _medical_tokens(gold)
    dial_tok  = _medical_tokens(dialogue)

    hallucinations = sorted(draft_tok - dial_tok)[:8]
    omissions      = sorted((gold_tok & dial_tok) - draft_tok)[:8]

    overlap = len(draft_tok & gold_tok) / max(len(gold_tok), 1)
    verdict = "GOOD" if overlap > 0.7 else "NEEDS_REVISION" if overlap > 0.4 else "POOR"

    hall_str = ", ".join(hallucinations) if hallucinations else "None identified."
    omit_str = ", ".join(omissions) if omissions else "None identified."
    acc_str  = (
        "Clinical terminology and reasoning are consistent with the dialogue."
        if verdict == "GOOD" else
        "Terminology and clinical reasoning require review given the "
        "discrepancies noted above."
    )

    return (
        f"1. HALLUCINATIONS: {hall_str}\n\n"
        f"2. OMISSIONS: {omit_str}\n\n"
        f"3. CLINICAL ACCURACY: {acc_str}\n\n"
        f"4. FORMATTING: Structure follows standard "
        f"{dim.capitalize()} section format.\n\n"
        f"VERDICT: {verdict}"
    )


# --- Formatting helpers --------------------------------------------------------

def format_drafter(dialogue, soap_text, dim):
    return {"messages": [
        {"role": "system",    "content": drafter_system(dim)},
        {"role": "user",      "content": f"Draft the {dim.capitalize()} section from the following consultation dialogue:\n\n{dialogue}"},
        {"role": "assistant", "content": soap_text},
    ]}


def format_critic(dialogue, draft, critique, dim):
    return {"messages": [
        {"role": "system", "content": critic_system(dim)},
        {"role": "user",   "content": (
            f"Review the following draft {dim.capitalize()} section against "
            f"the source consultation dialogue.\n\n"
            f"Source consultation dialogue:\n{dialogue}\n\n"
            f"Draft {dim.capitalize()} section to review:\n{draft}"
        )},
        {"role": "assistant", "content": critique},
    ]}


def format_refiner(dialogue, draft, critique, gold, dim):
    return {"messages": [
        {"role": "system", "content": refiner_system(dim)},
        {"role": "user",   "content": (
            f"Produce the final revised {dim.capitalize()} section.\n\n"
            f"Source consultation dialogue:\n{dialogue}\n\n"
            f"Initial draft:\n{draft}\n\n"
            f"Peer critique:\n{critique}"
        )},
        {"role": "assistant", "content": gold},
    ]}


# --- Write JSONL ---------------------------------------------------------------

def _write_jsonl(records, path):
    with open(path, "w", encoding="utf-8") as f:
        for rec in records:
            f.write(json.dumps(rec, ensure_ascii=False) + "\n")


def process_swarm_data(df, split, out_dir):
    df = df.reset_index(drop=True)
    cross_pairs = build_cross_pairs(df)

    for dim, cfg in SWARM_DIMS.items():
        col = cfg["column"]

        # -- Drafter --
        drafter_recs = []
        for idx in range(len(df)):
            soap = df[col].iloc[idx]
            if not isinstance(soap, str) or soap.strip() == "":
                continue
            drafter_recs.append(format_drafter(df["Dialogue"].iloc[idx], soap, dim))

        _write_jsonl(drafter_recs, f"{out_dir}/{split}_drafter_{dim}.jsonl")

        # -- Critic + Refiner (from cross-pairs) --
        critic_recs, refiner_recs = [], []
        for idx, cross_idx in cross_pairs:
            dialogue = df["Dialogue"].iloc[idx]
            gold     = df[col].iloc[idx]
            draft    = df[col].iloc[cross_idx]
            if not isinstance(gold, str) or not isinstance(draft, str):
                continue
            if gold.strip() == "" or draft.strip() == "":
                continue

            critique = generate_synthetic_critique(dialogue, draft, gold, dim)
            critic_recs.append(format_critic(dialogue, draft, critique, dim))
            refiner_recs.append(format_refiner(dialogue, draft, critique, gold, dim))

        _write_jsonl(critic_recs,  f"{out_dir}/{split}_critic_{dim}.jsonl")
        _write_jsonl(refiner_recs, f"{out_dir}/{split}_refiner_{dim}.jsonl")

        print(f"  {dim:<12s}  drafter={len(drafter_recs):>5}  "
              f"critic={len(critic_recs):>5}  refiner={len(refiner_recs):>5}")


# --- Generate all swarm training and validation data ---------------------------

random.seed(SEED)

swarm_train_df = train_df.drop(["Note"], axis=1)
swarm_val_df   = val_df.drop(["Note"], axis=1)
swarm_test_df  = test_df.drop(["Note"], axis=1)

os.makedirs("swarm_agents/data/training",        exist_ok=True)
os.makedirs("swarm_agents/data/validation",      exist_ok=True)
os.makedirs("swarm_agents/data/test",            exist_ok=True)

print("Training data:")
process_swarm_data(swarm_train_df, "training",   "swarm_agents/data/training")

print("\nValidation data:")
process_swarm_data(swarm_val_df,   "validation", "swarm_agents/data/validation")

print("\nTest data:")
process_swarm_data(swarm_test_df,  "test",       "swarm_agents/data/test")
# Out:
# Training data:
#   subjective    drafter= 7222  critic= 7222  refiner= 7222
#   objective     drafter= 7222  critic= 7222  refiner= 7222
#   assessment    drafter= 7222  critic= 7222  refiner= 7222
#   plan          drafter= 7222  critic= 7222  refiner= 7222
#
# Validation data:
#   subjective    drafter=  802  critic=  802  refiner=  802
#   objective     drafter=  802  critic=  802  refiner=  802
#   assessment    drafter=  802  critic=  802  refiner=  802
#   plan          drafter=  802  critic=  802  refiner=  802
#
# Test data:
#   subjective    drafter= 2006  critic= 2006  refiner= 2006
#   objective     drafter= 2006  critic= 2006  refiner= 2006
#   assessment    drafter= 2006  critic= 2006  refiner= 2006
#   plan          drafter= 2006  critic= 2006  refiner= 2006

# %%
# Copy data to small (3B) study directories (identical data, different model)
import shutil

COPY_PAIRS = [
    ("single_agent/data",  "single_agent_small/data"),
    ("multi_agents/data",  "multi_agents_small/data"),
    ("swarm_agents/data",  "swarm_agents_small/data"),
]

for src, dst in COPY_PAIRS:
    if os.path.exists(dst):
        shutil.rmtree(dst)
    shutil.copytree(src, dst)
    print(f"Copied {src} -> {dst}")
# Out:
# Copied single_agent/data -> single_agent_small/data
# Copied multi_agents/data -> multi_agents_small/data
# Copied swarm_agents/data -> swarm_agents_small/data

# %%
# Export as CSV
# train_df.to_csv("training_data_llm.csv")
# val_df.to_csv("validation_data_llm.csv")
# test_df.to_csv("test_data_llm.csv")

# %%
# Export as JSON
# train_df.to_json("training_data_llm.json", orient="records")
# val_df.to_json("validation_data_llm.json", orient="records")
# test_df.to_json("test_data_llm.json", orient="records")
